# %%
var1 = var2 = var3 = 1
print(var1,' ', var2,' ', var3)
# Out:
# 1   1   1

# %%
firstName = input("Enter your first name")
secondName = input("Enter your second name")
semester = input("Enter your sem")
# Out:
# Enter your first namekrutika
# Enter your second namedakhre
# Enter your sem6

# %%
x=68
print(chr(x))
char = 'D'
print(ord(char))
# Out:
# D
# 68

# %%
print('ACROPOLIS '* 10)
# Out:
# ACROPOLIS ACROPOLIS ACROPOLIS ACROPOLIS ACROPOLIS ACROPOLIS ACROPOLIS ACROPOLIS ACROPOLIS ACROPOLIS

# %%
for i in range(5):
  print("*"*i)

  print("\n")
  for i in range(4,0,-1):
    print("*"*i)
# Out:
# ****
# ***
# **
# *
# *
#
#
# ****
# ***
# **
# *
# **
#
#
# ****
# ***
# **
# *
# ***
#
#
# ****
# ***
# **
# *
# ****
#
#
# ****
# ***
# **
# *

# %%
for i in range(1,6):
   print (" "*(6-i),"*"*i)
# Out:
#       *
#      **
#     ***
#    ****
#   *****

# %%
val=20
age =45
print(f"{val} value is even and age is {age}")
# Out:
# 20 value is even and age is 45

# %%
a, b, c = 10,20,30
print(a, b, c, sep= ';', end= ' :')
# Out:
# 10;20;30 :

# %%
word = 'PYTNON'
a,b,c,d,e,f =wordprint(a,b,c,d,e,f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1222311451.py in <cell line: 0>()
#       1 word = 'PYTNON'
# ----> 2 a,b,c,d,e,f =wordprint(a,b,c,d,e,f)
#
# NameError: name 'wordprint' is not defined

# %%
x = 5
y = 10
print ('the value of x is {} and y is {}' .format(x,y))
# Out:
# the value of x is 5 and y is 10

# %%
print('I like {1} and {0}' .format('ice cream','chocolate'))
# Out:
# I like chocolate and ice cream

# %%
print('Hello (name), (greeting)' .format)

# %%
raman='coffee'
riya='tea'
raman, riya = riya, raman
print("raman : {}" .format(raman))
print("riya : {}" .format(riya ))
# Out:
# raman : tea
# riya : coffee

# %%
e,f,g,h,i,j='Python'
s=ord(e)+ord(f)+ord(g)+ord(h)+ord(i)+ord(j)
print(s)
# Out:
# 642

# %%
import math
print(math.sqrt(9))
print(math.floor(10.8))
print(math.ceil(10.5))
math.pi
# Out:
# 3.0
# 10
# 11
# 3.141592653589793

# %%
import random
x = random.random()
print("x =",x)
x = random.randomint()
print("x =",x)

# %%
import datetime
date = datetime.datetime.now().date()
year = date.datetime.now().year
month = date.datetime.now().month
day= date.datetime.now().day

print(date)
print(year)
print(month)
print(day)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-354850558.py in <cell line: 0>()
#       1 import datetime
#       2 date = datetime.datetime.now().date()
# ----> 3 year = date.datetime.now().year
#       4 month = date.datetime.now().month
#       5 day= date.datetime.now().day
#
# AttributeError: 'datetime.date' object has no attribute 'datetime'

# %%
import calendar

year = int(input ("Enter Year : "))
month = int(input("Enter the Month : "))
print (calendar,month(year, month))
# Out:
# Enter Year : 1999
# Enter the Month : 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2933116178.py in <cell line: 0>()
#       3 year = int(input ("Enter Year : "))
#       4 month = int(input("Enter the Month : "))
# ----> 5 print (calendar,month(year, month))
#
# TypeError: 'int' object is not callable
